# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\omkar\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\omkar\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omkar\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\omkar\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\omkar\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\omkar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv("groceries - groceries.csv", header=None)
df.head()
# Out:
#         0               1                    2             3             4   \
# 0  Item(s)          Item 1               Item 2        Item 3        Item 4
# 1        4    citrus fruit  semi-finished bread     margarine   ready soups
# 2        3  tropical fruit               yogurt        coffee           NaN
# 3        1      whole milk                  NaN           NaN           NaN
# 4        4       pip fruit               yogurt  cream cheese  meat spreads
#
#        5       6       7       8       9   ...       23       24       25  \
# 0  Item 5  Item 6  Item 7  Item 8  Item 9  ...  Item 23  Item 24  Item 25
# 1     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN
#
#         26       27       28       29       30       31       32
# 0  Item 26  Item 27  Item 28  Item 29  Item 30  Item 31  Item 32
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 33 columns]

# %%
transactions = df.apply(lambda row: row.dropna().tolist(), axis=1).tolist()

# %%
te = TransactionEncoder()
te_data = te.fit_transform(transactions)
encoded_df = pd.DataFrame(te_data, columns=te.columns_)

# %%
frequent_itemsets = apriori(encoded_df, min_support=0.02, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

# %%
print("Frequent Itemsets:\n", frequent_itemsets.head())
print("\nAssociation Rules:\n", rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head())
# Out:
# Frequent Itemsets:
#      support itemsets
# 0  0.219500      (1)
# 1  0.025010     (10)
# 2  0.167039      (2)
# 3  0.132066      (3)
# 4  0.102176      (4)
#
# Association Rules:
#       antecedents   consequents   support  confidence      lift
# 0  (canned beer)           (1)  0.026434    0.340314  1.550408
# 1            (5)  (whole milk)  0.026230    0.301754  1.181081
# 2            (6)  (whole milk)  0.027450    0.418605  1.638438
# 3            (7)  (whole milk)  0.021452    0.387156  1.515347
# 4            (8)  (whole milk)  0.020842    0.468037  1.831917
